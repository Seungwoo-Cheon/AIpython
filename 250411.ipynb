# %%
id = '251120-3870311'

if id[7] == '1' or '3':
  print('남자')
else:
  print('여자')
# Out:
# 남자

# %%
s = input('문자열: ')

for i in range(len(a)-1,-1,-1):
  print(a[i],end='')
# Out:
# 문자열: 12345
# 54321

# %%
s1 = input('문자열: ')
s2 = ''

for i in range(len(s1)-1,-1,-1):
  s2 += s1[i]

if s1 == s2:
  print('회문')
else:
  print('회문아님')
# Out:
# 문자열: 우영우
# 회문

# %%
l_lower = []

while True:
  s = input('영어 단어 또는 exit')
  if s == 'exit':
    break
  l_lower.append(s.lower())
for a in l_lower:
  print(a)
# Out:
# 영어 단어 또는 exithello
# 영어 단어 또는 exitPYTHON
# 영어 단어 또는 exitexit
# hello
# python

# %%
s = '부산시 금정구'

print(s.split(' '))
# Out:
# ['부산시', '금정구']

# %%
ㅣ = ['부산시', '금정구']

print(','.join(ㅣ))
# Out:
# 부산시,금정구

# %%
pw = input('비밀번호를 입력하시오: ')

while True:
  if pw.isalnum() == True:
    if (pw.isalpha() != True) and (pw.isdigit() != True):
      print('통과')
      break
    else:
      pw = input('비밀번호를 다시 입력하시오: ')
  else:
    pw = input('비밀번호를 다시 입력하시오: ')
# Out:
# 비밀번호를 입력하시오: 1234
# 비밀번호를 다시 입력하시오: abcd
# 비밀번호를 다시 입력하시오: 123abc
# 통과

# %%
a = 1/3

print("%.2f" % a)
# Out:
# 0.33

# %%
a = 1/3

print(f"{a:.2f}")
# Out:
# 0.33
