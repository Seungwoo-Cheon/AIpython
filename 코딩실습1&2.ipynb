# %%
A, B = map(int,input().split())

n = A + B

print(n)
# Out:
# 1 5
# 6

# %%
cm = float(input())
kg = float(input())

m = cm / 100

BMI = kg / (m ** 2)
a = round(BMI,2)

print(a)
# Out:
# 135
# 43.01
# 23.6
